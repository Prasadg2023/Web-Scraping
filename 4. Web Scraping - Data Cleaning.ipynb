# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("laptop_raw_data.csv")

# %%
df
# Out:
#                                          Product Title Product Price  \
# 0    MICROSOFT Surface Laptop (7th Edition) AI PC S...     ₹1,63,990
# 1    Samsung Galaxy Book4 Edge Series Copilot AI-PC...       ₹64,990
# 2    ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 3    Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹26,990
# 4    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹17,990
# ..                                                 ...           ...
# 979  ASUS Vivobook S16 OLED (2025) with Backlit Key...       ₹74,250
# 980  MOTOROLA Motobook 60 Full Metal OLED (i7 14th ...       ₹66,990
# 981  ASUS Vivobook 15 (2025) (i5 14th Gen) with MSO...       ₹53,990
# 982  MSI Modern 14 Intel Core i5 12th Gen 1235U - (...       ₹47,990
# 983  Lenovo IdeaPad Slim 3 Intel Core i5 13th Gen 1...       ₹65,000
#
#      Product Rating               Product Review  \
# 0               NaN                          NaN
# 1               4.4  2,015 Ratings & 175 Reviews
# 2               4.3     355 Ratings & 32 Reviews
# 3               3.9  3,574 Ratings & 275 Reviews
# 4               3.8  7,507 Ratings & 663 Reviews
# ..              ...                          ...
# 979             4.5     777 Ratings & 56 Reviews
# 980             4.4     711 Ratings & 80 Reviews
# 981             4.3   1,231 Ratings & 90 Reviews
# 982             4.4     359 Ratings & 36 Reviews
# 983             NaN                          NaN
#
#                                        Product Feature
# 0    Snapdragon X Elite Processor16 GB LPDDR5X RAMW...
# 1    Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 2    Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 3    Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 4    Intel Celeron Dual Core Processor8 GB DDR4 RAM...
# ..                                                 ...
# 979  Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 980  Intel Core 7 (Series 2) Processor16 GB DDR5 RA...
# 981  Intel Core 5 Processor16 GB DDR4 RAMWindows 11...
# 982  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 983  Intel Core i5 Processor (13th Gen)16 GB LPDDR5...
#
# [984 rows x 5 columns]

# %%
df["Product Feature"].iloc[0]
# Out:
# 'Snapdragon X Elite Processor16 GB LPDDR5X RAMWindows 11 Operating System512 GB SSD38.1 cm (15 Inch) Touchscreen Display1 Year Onsite Warranty'

# %%
data = ''' 
Intel Celeron Quad Core Processor (12th Gen)8 GB LPDDR5 RAM64 bit Windows 11 Home Operating System256 GB SSD35.81 cm (14.1 inch) DisplayWPS Office, Operating System Software1 Year Onsite Warranty
Intel Core i5 Processor (12th Gen)16 GB DDR4 RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 inch) Display1 Year Onsite Warranty
MediaTek Kompanio 520 Processor4 GB LPDDR4X RAMChrome Operating System29.46 cm (11.6 Inch) Display1 Year Carry-in Warranty
AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) Display1 Year Carry-in Warranty
Intel Celeron Dual Core Processor8 GB DDR4 RAM64 bit Windows 11 Home Operating System512 GB SSD29.46 cm (11.6 inch) Display1 Year Warranty
Intel Celeron Dual Core Processor8 GB LPDDR4X RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 inch) Display1 Year International Travelers Warranty (ITW)
Intel Celeron Dual Core Processor8 GB DDR4 RAM64 bit Windows 11 Home Operating System256 GB SSD29.46 cm (11.6 inch) Display1 Year Warranty
MediaTek MediaTek Kompanio 838 Processor8 GB LPDDR4X RAMChrome Operating System70.64 cm (27.81 cm) Touchscreen Display1 Year Onsite Warranty
Intel Core i3 Processor (13th Gen)16 GB DDR4 RAMWindows 11 Operating System512 GB SSD35.56 cm (14 Inch) Display1 Year Carry-in Warranty
Intel Core i3 Processor (12th Gen)8 GB DDR4 RAM64 bit Windows 11 Operating System512 GB SSD35.56 cm (14 Inch) Display1 Year Domestic Warranty
Intel Core i3 Processor (13th Gen)8 GB DDR4 RAM64 bit Windows 11 Home Operating System256 GB SSD35.56 cm (14 inch) Display1 Year Warranty
AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) Display1 Year Carry-in Warranty
Intel Core i3 Processor (13th Gen)8 GB LPDDR4X RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) Display1 Year Onsite Warranty
Intel Core i5 Processor (12th Gen)16 GB LPDDR5 RAM64 bit Windows 11 Home Operating System1 TB SSD39.62 cm (15.6 inch) Display1 Year Onsite warranty
Intel Core i5 Processor (13th Gen)16 GB DDR5 RAMWindows 11 Home Operating System512 GB SSD35.56 cm (14 inch) DisplayMicrosoft Office Home 2024 (Lifetime Validity ) + Microsoft 365 Basic*(1-Year Validity), One-Month Membership of Adobe Creative Cloud All Apps, McAfee 1 year1 Year Onsite Warranty
MediaTek MediaTek Kompanio 528 Processor4 GB LPDDR4X RAMChrome Operating System29.46 cm (11.6 Inch) Display1 Year Carry-in Warranty
Intel Core i7 Processor (12th Gen)16 GB DDR4 RAMWindows 11 Operating System512 GB SSD35.56 cm (14 inch) Display1 Year Warranty Term
Intel Core i5 Processor (13th Gen)16 GB DDR4 RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 inch) DisplayWindows 11 and Microsoft Office Home & Student Edition 20241 Year Carry-in Warranty
Intel Core i5 Processor (13th Gen)16 GB DDR4 RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) Display1 Year Onsite Warranty
Intel Celeron Dual Core Processor8 GB LPDDR4X RAMWindows 11 Operating System512 GB SSD35.56 cm (14 Inch) Display1 Year Carry-in Warranty'''

# %%
# Processor
pattern = r'(?:Intel|MediaTek|Snapdragon|Apple|AMD)[\s\w]+Processor(?:\s\([\d+\w+\s]+\))?'

word= re.findall(pattern, data)
word
# Out:
# ['Intel Celeron Quad Core Processor (12th Gen)',
#  'Intel Core i5 Processor (12th Gen)',
#  'MediaTek Kompanio 520 Processor',
#  'AMD Ryzen 7 Octa Core Processor',
#  'Intel Celeron Dual Core Processor',
#  'Intel Celeron Dual Core Processor',
#  'Intel Celeron Dual Core Processor',
#  'MediaTek MediaTek Kompanio 838 Processor',
#  'Intel Core i3 Processor (13th Gen)',
#  'Intel Core i3 Processor (12th Gen)',
#  'Intel Core i3 Processor (13th Gen)',
#  'AMD Ryzen 5 Hexa Core Processor',
#  'Intel Core i3 Processor (13th Gen)',
#  'Intel Core i5 Processor (12th Gen)',
#  'Intel Core i5 Processor (13th Gen)',
#  'MediaTek MediaTek Kompanio 528 Processor',
#  'Intel Core i7 Processor (12th Gen)',
#  'Intel Core i5 Processor (13th Gen)',
#  'Intel Core i5 Processor (13th Gen)',
#  'Intel Celeron Dual Core Processor']

# %%
len(word)
# Out:
# 20

# %%
# RAM
pattern = r"\d+\sGB[\s\w]*RAM" 
ram = re.findall(pattern, data)
ram, len(ram)
# Out:
# (['8 GB LPDDR5 RAM',
#   '16 GB DDR4 RAM',
#   '4 GB LPDDR4X RAM',
#   '16 GB DDR4 RAM',
#   '8 GB DDR4 RAM',
#   '8 GB LPDDR4X RAM',
#   '8 GB DDR4 RAM',
#   '8 GB LPDDR4X RAM',
#   '16 GB DDR4 RAM',
#   '8 GB DDR4 RAM',
#   '8 GB DDR4 RAM',
#   '16 GB DDR4 RAM',
#   '8 GB LPDDR4X RAM',
#   '16 GB LPDDR5 RAM',
#   '16 GB DDR5 RAM',
#   '4 GB LPDDR4X RAM',
#   '16 GB DDR4 RAM',
#   '16 GB DDR4 RAM',
#   '16 GB DDR4 RAM',
#   '8 GB LPDDR4X RAM'],
#  20)

# %%
# OS

pattern = r'(?:Windows|Chrome|MacOs)[\s\w]+Operating\sSystem'
os = re.findall(pattern, data)
os, len(os)
# Out:
# (['Windows 11 Home Operating System',
#   'Windows 11 Home Operating System',
#   'Chrome Operating System',
#   'Windows 11 Operating System',
#   'Windows 11 Home Operating System',
#   'Windows 11 Home Operating System',
#   'Windows 11 Home Operating System',
#   'Chrome Operating System',
#   'Windows 11 Operating System',
#   'Windows 11 Operating System',
#   'Windows 11 Home Operating System',
#   'Windows 11 Operating System',
#   'Windows 11 Operating System',
#   'Windows 11 Home Operating System',
#   'Windows 11 Home Operating System',
#   'Chrome Operating System',
#   'Windows 11 Operating System',
#   'Windows 11 Home Operating System',
#   'Windows 11 Operating System',
#   'Windows 11 Operating System'],
#  20)

# %%
# Storage
pattern = r'\d+\s(?:GB|TB)\s(?:SSD|HDD)'
storage = re.findall(pattern, data)
storage,len(storage)
# Out:
# (['256 GB SSD',
#   '512 GB SSD',
#   '512 GB SSD',
#   '512 GB SSD',
#   '512 GB SSD',
#   '256 GB SSD',
#   '512 GB SSD',
#   '512 GB SSD',
#   '256 GB SSD',
#   '512 GB SSD',
#   '512 GB SSD',
#   '1 TB SSD',
#   '512 GB SSD',
#   '512 GB SSD',
#   '512 GB SSD',
#   '512 GB SSD',
#   '512 GB SSD'],
#  17)

# %%
# Display
pattern = r'\d+\.\d+\scm.*Display'
display = re.findall(pattern, data)
display, len(display)
# Out:
# (['35.81 cm (14.1 inch) Display',
#   '39.62 cm (15.6 inch) Display',
#   '29.46 cm (11.6 Inch) Display',
#   '39.62 cm (15.6 Inch) Display',
#   '29.46 cm (11.6 inch) Display',
#   '39.62 cm (15.6 inch) Display',
#   '29.46 cm (11.6 inch) Display',
#   '70.64 cm (27.81 cm) Touchscreen Display',
#   '35.56 cm (14 Inch) Display',
#   '35.56 cm (14 Inch) Display',
#   '35.56 cm (14 inch) Display',
#   '39.62 cm (15.6 Inch) Display',
#   '39.62 cm (15.6 Inch) Display',
#   '39.62 cm (15.6 inch) Display',
#   '35.56 cm (14 inch) Display',
#   '29.46 cm (11.6 Inch) Display',
#   '35.56 cm (14 inch) Display',
#   '39.62 cm (15.6 inch) Display',
#   '39.62 cm (15.6 Inch) Display',
#   '35.56 cm (14 Inch) Display'],
#  20)

# %%
# Warranty

pattern = r'\d\sY[Year|Years]+[\s\-\w]*(?:warranty|Warranty)'
warranty = re.findall(pattern, data)
warranty , len(warranty)
# Out:
# (['1 Year Onsite Warranty',
#   '1 Year Onsite Warranty',
#   '1 Year Carry-in Warranty',
#   '1 Year Carry-in Warranty',
#   '1 Year Warranty',
#   '1 Year International Travelers Warranty',
#   '1 Year Warranty',
#   '1 Year Onsite Warranty',
#   '1 Year Carry-in Warranty',
#   '1 Year Domestic Warranty',
#   '1 Year Warranty',
#   '1 Year Carry-in Warranty',
#   '1 Year Onsite Warranty',
#   '1 Year Onsite warranty',
#   '1 Year Onsite Warranty',
#   '1 Year Carry-in Warranty',
#   '1 Year Warranty',
#   '1 Year Carry-in Warranty',
#   '1 Year Onsite Warranty',
#   '1 Year Carry-in Warranty'],
#  20)

# %%
df.head()
# Out:
#                                        Product Title Product Price  \
# 0  MICROSOFT Surface Laptop (7th Edition) AI PC S...     ₹1,63,990
# 1  Samsung Galaxy Book4 Edge Series Copilot AI-PC...       ₹64,990
# 2  ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 3  Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹26,990
# 4  Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹17,990
#
#    Product Rating               Product Review  \
# 0             NaN                          NaN
# 1             4.4  2,015 Ratings & 175 Reviews
# 2             4.3     355 Ratings & 32 Reviews
# 3             3.9  3,574 Ratings & 275 Reviews
# 4             3.8  7,507 Ratings & 663 Reviews
#
#                                      Product Feature
# 0  Snapdragon X Elite Processor16 GB LPDDR5X RAMW...
# 1  Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 2  Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 3  Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 4  Intel Celeron Dual Core Processor8 GB DDR4 RAM...

# %%
df.columns
# Out:
# Index(['Product Title', 'Product Price', 'Product Rating', 'Product Review',
#        'Product Feature'],
#       dtype='object')

# %%
# Create New columns for Processor
regex = r'(?:Intel|MediaTek|Apple|AMD|Qualcomm|Snapdragon)[\s\w\(\)]+Processor(?:\s\([\d+\w+\s]+\))?'
df["Processor"] = df['Product Feature'].apply(lambda x: re.findall(regex, x)[0] if re.findall(regex, x) else None)
df
# Out:
#                                          Product Title Product Price  \
# 0    MICROSOFT Surface Laptop (7th Edition) AI PC S...     ₹1,63,990
# 1    Samsung Galaxy Book4 Edge Series Copilot AI-PC...       ₹64,990
# 2    ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 3    Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹26,990
# 4    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹17,990
# ..                                                 ...           ...
# 979  ASUS Vivobook S16 OLED (2025) with Backlit Key...       ₹74,250
# 980  MOTOROLA Motobook 60 Full Metal OLED (i7 14th ...       ₹66,990
# 981  ASUS Vivobook 15 (2025) (i5 14th Gen) with MSO...       ₹53,990
# 982  MSI Modern 14 Intel Core i5 12th Gen 1235U - (...       ₹47,990
# 983  Lenovo IdeaPad Slim 3 Intel Core i5 13th Gen 1...       ₹65,000
#
#      Product Rating               Product Review  \
# 0               NaN                          NaN
# 1               4.4  2,015 Ratings & 175 Reviews
# 2               4.3     355 Ratings & 32 Reviews
# 3               3.9  3,574 Ratings & 275 Reviews
# 4               3.8  7,507 Ratings & 663 Reviews
# ..              ...                          ...
# 979             4.5     777 Ratings & 56 Reviews
# 980             4.4     711 Ratings & 80 Reviews
# 981             4.3   1,231 Ratings & 90 Reviews
# 982             4.4     359 Ratings & 36 Reviews
# 983             NaN                          NaN
#
#                                        Product Feature  \
# 0    Snapdragon X Elite Processor16 GB LPDDR5X RAMW...
# 1    Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 2    Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 3    Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 4    Intel Celeron Dual Core Processor8 GB DDR4 RAM...
# ..                                                 ...
# 979  Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 980  Intel Core 7 (Series 2) Processor16 GB DDR5 RA...
# 981  Intel Core 5 Processor16 GB DDR4 RAMWindows 11...
# 982  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 983  Intel Core i5 Processor (13th Gen)16 GB LPDDR5...
#
#                               Processor
# 0          Snapdragon X Elite Processor
# 1       Qualcomm Snapdragon X Processor
# 2               Intel Core i3 Processor
# 3     Intel Celeron Dual Core Processor
# 4     Intel Celeron Dual Core Processor
# ..                                  ...
# 979     Qualcomm Snapdragon X Processor
# 980   Intel Core 7 (Series 2) Processor
# 981              Intel Core 5 Processor
# 982  Intel Core i5 Processor (12th Gen)
# 983  Intel Core i5 Processor (13th Gen)
#
# [984 rows x 6 columns]

# %%
df[df["Processor"].isna()]
# Out:
# Empty DataFrame
# Columns: [Product Title, Product Price, Product Rating, Product Review, Product Feature, Processor]
# Index: []

# %%
# Create New columns for RAM
regex = r"\d+\sGB[\s\w]*RAM"
df["RAM"] = df['Product Feature'].apply(lambda x: re.findall(regex, x)[0] if re.findall(regex, x) else None)
df
# Out:
#                                          Product Title Product Price  \
# 0    MICROSOFT Surface Laptop (7th Edition) AI PC S...     ₹1,63,990
# 1    Samsung Galaxy Book4 Edge Series Copilot AI-PC...       ₹64,990
# 2    ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 3    Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹26,990
# 4    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹17,990
# ..                                                 ...           ...
# 979  ASUS Vivobook S16 OLED (2025) with Backlit Key...       ₹74,250
# 980  MOTOROLA Motobook 60 Full Metal OLED (i7 14th ...       ₹66,990
# 981  ASUS Vivobook 15 (2025) (i5 14th Gen) with MSO...       ₹53,990
# 982  MSI Modern 14 Intel Core i5 12th Gen 1235U - (...       ₹47,990
# 983  Lenovo IdeaPad Slim 3 Intel Core i5 13th Gen 1...       ₹65,000
#
#      Product Rating               Product Review  \
# 0               NaN                          NaN
# 1               4.4  2,015 Ratings & 175 Reviews
# 2               4.3     355 Ratings & 32 Reviews
# 3               3.9  3,574 Ratings & 275 Reviews
# 4               3.8  7,507 Ratings & 663 Reviews
# ..              ...                          ...
# 979             4.5     777 Ratings & 56 Reviews
# 980             4.4     711 Ratings & 80 Reviews
# 981             4.3   1,231 Ratings & 90 Reviews
# 982             4.4     359 Ratings & 36 Reviews
# 983             NaN                          NaN
#
#                                        Product Feature  \
# 0    Snapdragon X Elite Processor16 GB LPDDR5X RAMW...
# 1    Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 2    Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 3    Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 4    Intel Celeron Dual Core Processor8 GB DDR4 RAM...
# ..                                                 ...
# 979  Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 980  Intel Core 7 (Series 2) Processor16 GB DDR5 RA...
# 981  Intel Core 5 Processor16 GB DDR4 RAMWindows 11...
# 982  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 983  Intel Core i5 Processor (13th Gen)16 GB LPDDR5...
#
#                               Processor                RAM
# 0          Snapdragon X Elite Processor  16 GB LPDDR5X RAM
# 1       Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 2               Intel Core i3 Processor      8 GB DDR4 RAM
# 3     Intel Celeron Dual Core Processor  12 GB LPDDR4X RAM
# 4     Intel Celeron Dual Core Processor      8 GB DDR4 RAM
# ..                                  ...                ...
# 979     Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 980   Intel Core 7 (Series 2) Processor     16 GB DDR5 RAM
# 981              Intel Core 5 Processor     16 GB DDR4 RAM
# 982  Intel Core i5 Processor (12th Gen)     16 GB DDR4 RAM
# 983  Intel Core i5 Processor (13th Gen)   16 GB LPDDR5 RAM
#
# [984 rows x 7 columns]

# %%
df["RAM"].isna().sum()
# Out:
# np.int64(0)

# %%
# Create New columns for OS
regex = r'(?:Windows|Chrome)[\s\w]+Operating\sSystem'
df["OS"] = df['Product Feature'].apply(lambda x: re.findall(regex, x)[0] if re.findall(regex, x) else None)
df
# Out:
#                                          Product Title Product Price  \
# 0    MICROSOFT Surface Laptop (7th Edition) AI PC S...     ₹1,63,990
# 1    Samsung Galaxy Book4 Edge Series Copilot AI-PC...       ₹64,990
# 2    ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 3    Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹26,990
# 4    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹17,990
# ..                                                 ...           ...
# 979  ASUS Vivobook S16 OLED (2025) with Backlit Key...       ₹74,250
# 980  MOTOROLA Motobook 60 Full Metal OLED (i7 14th ...       ₹66,990
# 981  ASUS Vivobook 15 (2025) (i5 14th Gen) with MSO...       ₹53,990
# 982  MSI Modern 14 Intel Core i5 12th Gen 1235U - (...       ₹47,990
# 983  Lenovo IdeaPad Slim 3 Intel Core i5 13th Gen 1...       ₹65,000
#
#      Product Rating               Product Review  \
# 0               NaN                          NaN
# 1               4.4  2,015 Ratings & 175 Reviews
# 2               4.3     355 Ratings & 32 Reviews
# 3               3.9  3,574 Ratings & 275 Reviews
# 4               3.8  7,507 Ratings & 663 Reviews
# ..              ...                          ...
# 979             4.5     777 Ratings & 56 Reviews
# 980             4.4     711 Ratings & 80 Reviews
# 981             4.3   1,231 Ratings & 90 Reviews
# 982             4.4     359 Ratings & 36 Reviews
# 983             NaN                          NaN
#
#                                        Product Feature  \
# 0    Snapdragon X Elite Processor16 GB LPDDR5X RAMW...
# 1    Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 2    Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 3    Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 4    Intel Celeron Dual Core Processor8 GB DDR4 RAM...
# ..                                                 ...
# 979  Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 980  Intel Core 7 (Series 2) Processor16 GB DDR5 RA...
# 981  Intel Core 5 Processor16 GB DDR4 RAMWindows 11...
# 982  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 983  Intel Core i5 Processor (13th Gen)16 GB LPDDR5...
#
#                               Processor                RAM  \
# 0          Snapdragon X Elite Processor  16 GB LPDDR5X RAM
# 1       Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 2               Intel Core i3 Processor      8 GB DDR4 RAM
# 3     Intel Celeron Dual Core Processor  12 GB LPDDR4X RAM
# 4     Intel Celeron Dual Core Processor      8 GB DDR4 RAM
# ..                                  ...                ...
# 979     Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 980   Intel Core 7 (Series 2) Processor     16 GB DDR5 RAM
# 981              Intel Core 5 Processor     16 GB DDR4 RAM
# 982  Intel Core i5 Processor (12th Gen)     16 GB DDR4 RAM
# 983  Intel Core i5 Processor (13th Gen)   16 GB LPDDR5 RAM
#
#                                    OS
# 0         Windows 11 Operating System
# 1         Windows 11 Operating System
# 2    Windows 11 Home Operating System
# 3         Windows 11 Operating System
# 4    Windows 11 Home Operating System
# ..                                ...
# 979  Windows 11 Home Operating System
# 980       Windows 11 Operating System
# 981  Windows 11 Home Operating System
# 982       Windows 11 Operating System
# 983       Windows 11 Operating System
#
# [984 rows x 8 columns]

# %%
# Create New columns for Storage
regex = r'\d+\s(?:GB|TB)\s(?:SSD|HDD)'
df["Storage"] = df['Product Feature'].apply(lambda x: re.findall(regex, x)[0] if re.findall(regex, x) else None)
df
# Out:
#                                          Product Title Product Price  \
# 0    MICROSOFT Surface Laptop (7th Edition) AI PC S...     ₹1,63,990
# 1    Samsung Galaxy Book4 Edge Series Copilot AI-PC...       ₹64,990
# 2    ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 3    Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹26,990
# 4    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹17,990
# ..                                                 ...           ...
# 979  ASUS Vivobook S16 OLED (2025) with Backlit Key...       ₹74,250
# 980  MOTOROLA Motobook 60 Full Metal OLED (i7 14th ...       ₹66,990
# 981  ASUS Vivobook 15 (2025) (i5 14th Gen) with MSO...       ₹53,990
# 982  MSI Modern 14 Intel Core i5 12th Gen 1235U - (...       ₹47,990
# 983  Lenovo IdeaPad Slim 3 Intel Core i5 13th Gen 1...       ₹65,000
#
#      Product Rating               Product Review  \
# 0               NaN                          NaN
# 1               4.4  2,015 Ratings & 175 Reviews
# 2               4.3     355 Ratings & 32 Reviews
# 3               3.9  3,574 Ratings & 275 Reviews
# 4               3.8  7,507 Ratings & 663 Reviews
# ..              ...                          ...
# 979             4.5     777 Ratings & 56 Reviews
# 980             4.4     711 Ratings & 80 Reviews
# 981             4.3   1,231 Ratings & 90 Reviews
# 982             4.4     359 Ratings & 36 Reviews
# 983             NaN                          NaN
#
#                                        Product Feature  \
# 0    Snapdragon X Elite Processor16 GB LPDDR5X RAMW...
# 1    Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 2    Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 3    Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 4    Intel Celeron Dual Core Processor8 GB DDR4 RAM...
# ..                                                 ...
# 979  Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 980  Intel Core 7 (Series 2) Processor16 GB DDR5 RA...
# 981  Intel Core 5 Processor16 GB DDR4 RAMWindows 11...
# 982  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 983  Intel Core i5 Processor (13th Gen)16 GB LPDDR5...
#
#                               Processor                RAM  \
# 0          Snapdragon X Elite Processor  16 GB LPDDR5X RAM
# 1       Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 2               Intel Core i3 Processor      8 GB DDR4 RAM
# 3     Intel Celeron Dual Core Processor  12 GB LPDDR4X RAM
# 4     Intel Celeron Dual Core Processor      8 GB DDR4 RAM
# ..                                  ...                ...
# 979     Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 980   Intel Core 7 (Series 2) Processor     16 GB DDR5 RAM
# 981              Intel Core 5 Processor     16 GB DDR4 RAM
# 982  Intel Core i5 Processor (12th Gen)     16 GB DDR4 RAM
# 983  Intel Core i5 Processor (13th Gen)   16 GB LPDDR5 RAM
#
#                                    OS     Storage
# 0         Windows 11 Operating System  512 GB SSD
# 1         Windows 11 Operating System  512 GB SSD
# 2    Windows 11 Home Operating System  512 GB SSD
# 3         Windows 11 Operating System  512 GB SSD
# 4    Windows 11 Home Operating System  128 GB SSD
# ..                                ...         ...
# 979  Windows 11 Home Operating System  512 GB SSD
# 980       Windows 11 Operating System    1 TB SSD
# 981  Windows 11 Home Operating System  512 GB SSD
# 982       Windows 11 Operating System  512 GB SSD
# 983       Windows 11 Operating System  512 GB SSD
#
# [984 rows x 9 columns]

# %%
# Create New columns for Display
regex = r'\d+\.\d+\scm.*Display'
df["Display"] = df['Product Feature'].apply(lambda x: re.findall(regex, x)[0] if re.findall(regex, x) else None)
df
# Out:
#                                          Product Title Product Price  \
# 0    MICROSOFT Surface Laptop (7th Edition) AI PC S...     ₹1,63,990
# 1    Samsung Galaxy Book4 Edge Series Copilot AI-PC...       ₹64,990
# 2    ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 3    Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹26,990
# 4    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹17,990
# ..                                                 ...           ...
# 979  ASUS Vivobook S16 OLED (2025) with Backlit Key...       ₹74,250
# 980  MOTOROLA Motobook 60 Full Metal OLED (i7 14th ...       ₹66,990
# 981  ASUS Vivobook 15 (2025) (i5 14th Gen) with MSO...       ₹53,990
# 982  MSI Modern 14 Intel Core i5 12th Gen 1235U - (...       ₹47,990
# 983  Lenovo IdeaPad Slim 3 Intel Core i5 13th Gen 1...       ₹65,000
#
#      Product Rating               Product Review  \
# 0               NaN                          NaN
# 1               4.4  2,015 Ratings & 175 Reviews
# 2               4.3     355 Ratings & 32 Reviews
# 3               3.9  3,574 Ratings & 275 Reviews
# 4               3.8  7,507 Ratings & 663 Reviews
# ..              ...                          ...
# 979             4.5     777 Ratings & 56 Reviews
# 980             4.4     711 Ratings & 80 Reviews
# 981             4.3   1,231 Ratings & 90 Reviews
# 982             4.4     359 Ratings & 36 Reviews
# 983             NaN                          NaN
#
#                                        Product Feature  \
# 0    Snapdragon X Elite Processor16 GB LPDDR5X RAMW...
# 1    Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 2    Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 3    Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 4    Intel Celeron Dual Core Processor8 GB DDR4 RAM...
# ..                                                 ...
# 979  Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 980  Intel Core 7 (Series 2) Processor16 GB DDR5 RA...
# 981  Intel Core 5 Processor16 GB DDR4 RAMWindows 11...
# 982  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 983  Intel Core i5 Processor (13th Gen)16 GB LPDDR5...
#
#                               Processor                RAM  \
# 0          Snapdragon X Elite Processor  16 GB LPDDR5X RAM
# 1       Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 2               Intel Core i3 Processor      8 GB DDR4 RAM
# 3     Intel Celeron Dual Core Processor  12 GB LPDDR4X RAM
# 4     Intel Celeron Dual Core Processor      8 GB DDR4 RAM
# ..                                  ...                ...
# 979     Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 980   Intel Core 7 (Series 2) Processor     16 GB DDR5 RAM
# 981              Intel Core 5 Processor     16 GB DDR4 RAM
# 982  Intel Core i5 Processor (12th Gen)     16 GB DDR4 RAM
# 983  Intel Core i5 Processor (13th Gen)   16 GB LPDDR5 RAM
#
#                                    OS     Storage  \
# 0         Windows 11 Operating System  512 GB SSD
# 1         Windows 11 Operating System  512 GB SSD
# 2    Windows 11 Home Operating System  512 GB SSD
# 3         Windows 11 Operating System  512 GB SSD
# 4    Windows 11 Home Operating System  128 GB SSD
# ..                                ...         ...
# 979  Windows 11 Home Operating System  512 GB SSD
# 980       Windows 11 Operating System    1 TB SSD
# 981  Windows 11 Home Operating System  512 GB SSD
# 982       Windows 11 Operating System  512 GB SSD
# 983       Windows 11 Operating System  512 GB SSD
#
#                                     Display
# 0     38.1 cm (15 Inch) Touchscreen Display
# 1              39.62 cm (15.6 inch) Display
# 2              39.62 cm (15.6 inch) Display
# 3                35.56 cm (14 Inch) Display
# 4              29.46 cm (11.6 inch) Display
# ..                                      ...
# 979              40.64 cm (16 inch) Display
# 980              35.56 cm (14 Inch) Display
# 981            39.62 cm (15.6 Inch) Display
# 982              35.56 cm (14 inch) Display
# 983  35.56 cm (14 Inch) Touchscreen Display
#
# [984 rows x 10 columns]

# %%
# Create New columns for Warranty
regex = r'\d\sY[Year|Years|YEARS]+[\s\-\w]*(?:warranty|Warranty)'
df["Warranty"] = df['Product Feature'].apply(lambda x: re.findall(regex, x)[0] if re.findall(regex, x) else None)
df
# Out:
#                                          Product Title Product Price  \
# 0    MICROSOFT Surface Laptop (7th Edition) AI PC S...     ₹1,63,990
# 1    Samsung Galaxy Book4 Edge Series Copilot AI-PC...       ₹64,990
# 2    ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 3    Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹26,990
# 4    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹17,990
# ..                                                 ...           ...
# 979  ASUS Vivobook S16 OLED (2025) with Backlit Key...       ₹74,250
# 980  MOTOROLA Motobook 60 Full Metal OLED (i7 14th ...       ₹66,990
# 981  ASUS Vivobook 15 (2025) (i5 14th Gen) with MSO...       ₹53,990
# 982  MSI Modern 14 Intel Core i5 12th Gen 1235U - (...       ₹47,990
# 983  Lenovo IdeaPad Slim 3 Intel Core i5 13th Gen 1...       ₹65,000
#
#      Product Rating               Product Review  \
# 0               NaN                          NaN
# 1               4.4  2,015 Ratings & 175 Reviews
# 2               4.3     355 Ratings & 32 Reviews
# 3               3.9  3,574 Ratings & 275 Reviews
# 4               3.8  7,507 Ratings & 663 Reviews
# ..              ...                          ...
# 979             4.5     777 Ratings & 56 Reviews
# 980             4.4     711 Ratings & 80 Reviews
# 981             4.3   1,231 Ratings & 90 Reviews
# 982             4.4     359 Ratings & 36 Reviews
# 983             NaN                          NaN
#
#                                        Product Feature  \
# 0    Snapdragon X Elite Processor16 GB LPDDR5X RAMW...
# 1    Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 2    Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 3    Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 4    Intel Celeron Dual Core Processor8 GB DDR4 RAM...
# ..                                                 ...
# 979  Qualcomm Snapdragon X Processor16 GB LPDDR5X R...
# 980  Intel Core 7 (Series 2) Processor16 GB DDR5 RA...
# 981  Intel Core 5 Processor16 GB DDR4 RAMWindows 11...
# 982  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 983  Intel Core i5 Processor (13th Gen)16 GB LPDDR5...
#
#                               Processor                RAM  \
# 0          Snapdragon X Elite Processor  16 GB LPDDR5X RAM
# 1       Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 2               Intel Core i3 Processor      8 GB DDR4 RAM
# 3     Intel Celeron Dual Core Processor  12 GB LPDDR4X RAM
# 4     Intel Celeron Dual Core Processor      8 GB DDR4 RAM
# ..                                  ...                ...
# 979     Qualcomm Snapdragon X Processor  16 GB LPDDR5X RAM
# 980   Intel Core 7 (Series 2) Processor     16 GB DDR5 RAM
# 981              Intel Core 5 Processor     16 GB DDR4 RAM
# 982  Intel Core i5 Processor (12th Gen)     16 GB DDR4 RAM
# 983  Intel Core i5 Processor (13th Gen)   16 GB LPDDR5 RAM
#
#                                    OS     Storage  \
# 0         Windows 11 Operating System  512 GB SSD
# 1         Windows 11 Operating System  512 GB SSD
# 2    Windows 11 Home Operating System  512 GB SSD
# 3         Windows 11 Operating System  512 GB SSD
# 4    Windows 11 Home Operating System  128 GB SSD
# ..                                ...         ...
# 979  Windows 11 Home Operating System  512 GB SSD
# 980       Windows 11 Operating System    1 TB SSD
# 981  Windows 11 Home Operating System  512 GB SSD
# 982       Windows 11 Operating System  512 GB SSD
# 983       Windows 11 Operating System  512 GB SSD
#
#                                     Display                      Warranty
# 0     38.1 cm (15 Inch) Touchscreen Display        1 Year Onsite Warranty
# 1              39.62 cm (15.6 inch) Display  1 Year Manufacturer Warranty
# 2              39.62 cm (15.6 inch) Display        1 Year Onsite Warranty
# 3                35.56 cm (14 Inch) Display      1 Year Carry-in Warranty
# 4              29.46 cm (11.6 inch) Display               1 Year Warranty
# ..                                      ...                           ...
# 979              40.64 cm (16 inch) Display        1 Year Onsite Warranty
# 980              35.56 cm (14 Inch) Display        1 Year Onsite Warranty
# 981            39.62 cm (15.6 Inch) Display        1 Year Onsite Warranty
# 982              35.56 cm (14 inch) Display        1 Year Onsite Warranty
# 983  35.56 cm (14 Inch) Touchscreen Display      1 Year Carry-in Warranty
#
# [984 rows x 11 columns]

# %%
df["Product Feature"].iloc[4]
# Out:
# 'Intel Celeron Dual Core Processor8 GB DDR4 RAM64 bit Windows 11 Home Operating System128 GB SSD29.46 cm (11.6 inch) Display1 Year Warranty'
