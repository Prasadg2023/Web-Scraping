# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
#Getting access by the website
url = "https://www.flipkart.com/"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}
response = requests.get(url, headers = headers)

# %%
response.status_code
# Out:
# 200

# %%
html_code = response.text
html_code[:2000]
# Out:
# '<!DOCTYPE html>  <html lang="en-IN" class="en-fonts-loaded useInterFont"> <head><link rel="dns-prefetch" href="https://1.rome.api.flipkart.com"><link rel="dns-prefetch" href="https://2.rome.api.flipkart.com"><link rel="preconnect" href="https://static-assets-web.flixcart.com" crossorigin> <link rel="preconnect" href="https://rukminim2.flixcart.com"><link rel="icon" href="https://static-assets-web.flixcart.com/batman-returns/batman-returns/p/images/logo_lite-cbb357.png" type="image/png"><link rel="apple-touch-icon" href="https://rukminim1.flixcart.com/www/192/192/promos/11/07/2024/cf1a3e0a-224b-4dd1-bb96-84abf3d298e2.png?q=100"><link rel="apple-touch-icon" sizes="192x192" href="https://rukminim1.flixcart.com/www/192/192/promos/11/07/2024/cf1a3e0a-224b-4dd1-bb96-84abf3d298e2.png?q=100"><link rel="apple-touch-icon" sizes="256x256" href="https://rukminim1.flixcart.com/www/256/256/promos/11/07/2024/d07db984-260e-484e-ac9d-6a9ddd35ebcb.png?q=100"><link rel="apple-touch-icon" sizes="384x384" href="https://rukminim1.flixcart.com/www/384/384/promos/11/07/2024/9acd440c-c685-4baa-8832-4f8bfe7da252.png?q=100"><link rel="apple-touch-icon" sizes="512x512" href="https://rukminim1.flixcart.com/www/512/512/promos/11/07/2024/e8f26305-4b9f-444f-a970-b70dc51e04ef.png?q=100"><meta name="apple-mobile-web-app-capable" content="yes"><link rel="apple-touch-startup-image" media="screen and (device-width: 430px) and (device-height: 932px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" href="https://rukminim1.flixcart.com/www/1290/2792/promos/21/07/2024/dc4cedcb-4f40-4188-8655-52496286257d.jpg?q=100"><link rel="apple-touch-startup-image" media="screen and (device-width: 393px) and (device-height: 852px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" href="https://rukminim1.flixcart.com/www/1179/2556/promos/19/07/2024/b7db38ec-bce9-47af-bc79-bc952ba0918d.png?q=100"><link rel="apple-touch-startup-image" media="screen and (device-width: 390px) and (device-heigh'

# %%
soup = BeautifulSoup(html_code)
soup.text[:2000]
# Out:
# "     Online Shopping India Mobile, Cameras, Lifestyle & more Online @ Flipkart.com             Search IconLoginNew customer?Sign UpMy ProfileFlipkart Plus ZoneOrdersWishlistRewardsGift CardsLoginCartBecome a SellerNotification Preferences24x7 Customer CareAdvertiseDownload AppMinutesMobiles & TabletsFashionElectronicsTVs & AppliancesHome & FurnitureFlight BookingsBeauty, Food..GroceryBest deals on smartphonesApple iPhone 16From ₹55,999*Galaxy S24 5GFrom ₹40,999Motorola-G57 PowerJust ₹13,999*Moto Edge 60 Fusion 5GFrom ₹18,999*Vivo T4x 5GFrom ₹14,999*Poco-C75 5GJust ₹7,999Samsung Galaxy A35 5GFrom₹17,999vivo T4 Lite 5GJust ₹11,499*Hang on, loading contentTop Stories :Brand DirectoryMost searched for on Flipkart:End of Season SaleChristmas SaleNew Year SaleMOTOROLA Edge 70Ray-Ban Meta Smart GlassesMOTOROLA g67 power 5GWedding SaleLehengaGoogle Pixel 10 Pro FoldiPhone 17iPhone Airvivo v60emoto g06 power 5giPhone 17 Pro MaxGoogle Pixel 10Google Pixel 10 ProGoogle Pixel 10 Pro XLSamsung Galaxy Z Flip7 5GREDMI Note 14 SE 5GMens WatchWomens WatchMen's JacketsNothing Phone 3SoundbarsRingsEarringsSony SoundbarsJewelleryAirpodsJBL SoundbarsUrbn Power BanksBoult Wireless EarphonesBose SoundbarsOneplus Wireless Earphonesvivo X Fold 5MOTOROLA Edge 60 5GSAMSUNG Galaxy S25 EdgeMOTOROLA Razr 60CMF Phone 2 ProGoogle Pixel 9ASAMSUNG F16Nothing Phone 3aiPhone 16eSAMSUNG Galaxy S25 UltraSAMSUNG Galaxy S25 PlusSAMSUNG Galaxy S25iPhone 16iPhone 16 PlusiPhone 16 ProiPhone 16 Pro Maxvivo V50OPPO Reno13 ProPOCO X7realme 14 Pro PlusREDMI Note 14 Pro+ 5GOPPO Find X8CMF by Nothing Phone 1Infinix Note 40 Pro 5GiPhone 15Infinix Note 40 5GVivo x 100SAMSUNG Flip5SAMSUNG Fold5Flipkart Axis Bank Super Elite Credit card5G Mobile PhonesGrievance RedressalTrack OrdersManage OrdersMobilesInfinix SMART 10OPPO Reno 14 ProMotorola g64 5GOPPO Reno 12Motorola G45 5GMotorola Edge 50 FusionRealme 12+  5GInfinix Smart 8vivo V30Samsung Galaxy S24 5GInfinix HOT 30iRealme 10 Pro 5GMotorola 5g PhoneRealme 5g Smartph"

# %% [markdown]
# # Analysis on prices of the products available in flipkart
# * **1) Laptops**

# %%
# identify the URL
url = 'https://www.flipkart.com/search?q=laptops'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"}

# Loading the webpage using requsts library
response = requests.get(url, headers= headers)
response
# Out:
# <Response [200]>

# %%
html_code = response.text
html_code[:2000]
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.aa1465.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.fbaef9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png"/><link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png"/><link rel="apple-touch-icon" href="/apple-touch-icon-57x57.png"/><meta name="twitter:card" content="app"><meta name="twitter:site" content="@flipkart"><meta name="twitter:creator" content="@flipkart"><meta name="twitter:title" content="Laptops- Buy Products Online at Best Price in India - All Categories | Flipkart.com"><meta name="twitter:description" content="Shop for electronics, apparels & more using our Flipkart app Free shipping & COD."><meta name="twitter:app:country" content="in"><meta name="al:ios:app_name" content="Flipkart"><meta name="al:ios:app_store_id" content="742044692"><meta name="twitter:app:name:iphone" content="Flipkart"><meta name="twitter:app:id:iphone" content="742044692"><meta name="twitter:app:url:iphone" content="http://dl.flipkart.com/'

# %%
soup = BeautifulSoup(html_code)
soup.text[:2000]
# Out:
# '  Laptops- Buy Products Online at Best Price in India - All Categories | Flipkart.com     Explore PlusLoginBecome a Seller More CartFiltersCATEGORIESComputersLaptopsPrice.......Min₹20000₹40000₹50000₹60000₹75000to₹20000₹40000₹50000₹60000₹75000₹75000+BrandTypeProcessorCore i5Core i3Core i7Ryzen 7 Quad CoreRyzen 5 Quad CoreCore i957 MOREProcessor GenerationRAM CapacitySSD CapacityScreen SizeOperating SystemWeightTouch ScreenProcessor BrandUsageDedicated Graphics MemoryFeaturesStorage TypeGraphics Memory TypeGraphic Processor NameHard Disk CapacityRam TypeAvailabilityDiscountCustomer Ratings4★ & above3★ & above2★ & above1★ & aboveUsage?GST Invoice AvailableOffersSpecial PriceNo Cost EMIRAM CapacityNeed help?Help me decideHomeComputersLaptopsShowing 1 – 24 of 2,364 results for "laptops"Sort ByRelevancePopularityPrice -- Low to HighPrice -- High to LowNewest FirstAdd to CompareLenovo Legion Go AMD Ryzen Z1 Extreme - (16 GB/512 GB SSD/Windows 11 Home) 8APU1 Handheld Gaming PC4.4114 Ratings\xa0&\xa015 ReviewsAMD Ryzen Z1 Extreme Processor16 GB LPDDR5X RAMWindows 11 Home Operating System512 GB SSD22.35 cm (8.8 inch) Touchscreen Display1 Year Carry in + 1 Year Accidental Damage Protection₹73,990₹1,25,89041% offUpto ₹22,000 Off on ExchangeBank OfferAdd to CompareASUS Vivobook Go 15 (2025) with Office 2024 + M365 Basic* Intel Core i3 N305 - (8 GB/512 GB SSD/Window...4.3360 Ratings\xa0&\xa032 ReviewsIntel Core i3 Processor8 GB DDR4 RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 inch) DisplayMicrosoft Office Home 2024 (Lifetime Validity ) + Microsoft 365 Basic*(1-Year Validity), McAfee 1 year1 Year Onsite Warranty₹39,990₹53,99025% offOnly 4 leftBank OfferAdd to CompareAcer Aspire 3 Intel Celeron Dual Core N4500 - (12 GB/512 GB SSD/Windows 11 Home) A324-45 Thin and Ligh...3.93,593 Ratings\xa0&\xa0275 ReviewsIntel Celeron Dual Core Processor12 GB LPDDR4X RAMWindows 11 Operating System512 GB SSD35.56 cm (14 Inch) Display1 Year Carry-in Warranty₹28,990₹32,99912% offOnly few leftUpto ₹22,0'

# %%
#extracting all laptops on the wepage
# Product title
titles = soup.find_all('div',attrs = {'class':'RG5Slk'})
for t in titles:
    print(t.text)
# Out:
# Lenovo Legion Go AMD Ryzen Z1 Extreme - (16 GB/512 GB SSD/Windows 11 Home) 8APU1 Handheld Gaming PC
# ASUS Vivobook Go 15 (2025) with Office 2024 + M365 Basic* Intel Core i3 N305 - (8 GB/512 GB SSD/Window...
# Acer Aspire 3 Intel Celeron Dual Core N4500 - (12 GB/512 GB SSD/Windows 11 Home) A324-45 Thin and Ligh...
# ASUS Expertbook P1 Intel Core i3 13th Gen 1315U - (8 GB/512 GB SSD/Windows 11 Home) P1503CVA-S70501WS ...
# Acer Aspire 3 Intel Celeron Dual Core - (8 GB/128 GB SSD/Windows 11 Home) A311-45 Thin and Light Lapto...
# walker Intel Celeron Dual Core N4020 - (4 GB/128 GB SSD/Windows 11 Home) NU14A1 Thin and Light Laptop
# ASUS Expertbook P1 Intel Core i3 13th Gen 1315U - (16 GB/512 GB SSD/Windows 11 Home) P1403CVA-S60938WS...
# Lenovo IdeaPad Slim 1 AMD Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15ACL6 | 15ALC7 ...
# Acer Aspire 3 Backlit AMD Ryzen 7 Octa Core 7730U - (16 GB/1 TB SSD/Windows 11 Home) A325-42 / AS15-42...
# Lenovo IdeaPad Slim 3 Next Gen AI PC WUXGA IPS Copilot + PC Qualcomm Snapdragon X - (16 GB/512 GB SSD/...
# HP 15s Intel Core i3 13th Gen 1315U - (8 GB/512 GB SSD/Windows 11 Home) 15-fd0006TU / 15-fd0569TU Thin...
# Acer Aspire 3 Intel Celeron Dual Core - (8 GB/512 GB SSD/Windows 11 Home) A311-45 Thin and Light Lapto...
# Lenovo 100e Chromebook Gen 4 MediaTek Kompanio 520 - (4 GB/32 GB EMMC Storage/Chrome OS) 82W00004HA Ch...
# Acer Aspire 3 AMD Ryzen 3 Quad Core 7330U - (8 GB/512 GB SSD/Windows 11 Home) AS15 42 / A325 42 Thin a...
# Ultimus APEX Pro Intel Pentium Quad Core N4200 - (4 GB/128 GB SSD/128 GB EMMC Storage/Windows 11 Home)...
# Lenovo IdeaPad Slim 1 AMD Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 11 Home) 15ALC7 Thin and...
# HP 15 Laptop with Backlit Keyboard & MSO'2024, AMD Ryzen 7 Octa Core 7730U - (16 GB/512 GB SSD/Windows...
# Acer Aspire 3 Intel Celeron Dual Core N4500 - (8 GB/512 GB SSD/Windows 11 Home) A325-45 Thin and Light...
# ASUS Vivobook Go 15 AMD Ryzen 3 Quad Core 7320U - (8 GB/512 GB SSD/Windows 11 Home) E1504FA-NJ131WS | ...
# HP AMD Ryzen 5 Quad Core 7520U - (16 GB/512 GB SSD/Windows 11 Home) 15-fc0690AU Thin and Light Laptop
# Acer 3 Years Warranty Aspire 3 (2025) Intel Core i3 13th Gen 1305U - (16 GB/512 GB SSD/Windows 11 Home...
# Acer Aspire 15 AMD Ryzen 5 Hexa Core 7430U - (16 GB/512 GB SSD/Windows 11 Home) Aspire AS15-42 Thin an...
# DELL 15 (Core i3 14th Gen) Intel Core 3 100U - (8 GB/512 GB SSD/Windows 11 Home) DC15250 Thin and Ligh...
# Primebook 2 Pro (2025) in-Built AI MediaTek Helio G99 (MT8781) - (8 GB/128 GB/Android 15) PBG9914128#4...

# %%
len(titles)
# Out:
# 24

# %%
# product rating
ratings = soup.find_all('div', attrs = {'class':'MKiFS6'})
for r in ratings:
    print(r.text)
# Out:
# 4.4
# 4.3
# 3.9
# 4.3
# 3.8
# 3.7
# 4.3
# 4.2
# 4.1
# 4.3
# 4.2
# 3.8
# 4
# 4.1
# 2
# 4.2
# 4.8
# 3.9
# 4.3
# 4.1
# 4
# 4.1
# 3.9
# 4.4
# 4.1
# 4
# 5
# 4.1
# 5
# 1
# 3.8
# 5
# 1
# 4.3
# 4
# 4
# 3.9
# 4
# 5

# %%
len(ratings)
# Out:
# 39

# %%
# product price
prices = soup.find_all('div', attrs = {'class':'hZ3P6w DeU9vF'})
for p in prices:
    print(p.text)
# Out:
# ₹73,990
# ₹39,990
# ₹28,990
# ₹36,990
# ₹18,990
# ₹11,990
# ₹40,990
# ₹34,400
# ₹45,990
# ₹49,990
# ₹38,010
# ₹24,699
# ₹13,990
# ₹29,990
# ₹13,990
# ₹38,990
# ₹50,990
# ₹26,990
# ₹32,990
# ₹41,390
# ₹37,490
# ₹39,990
# ₹37,990
# ₹18,990

# %%
len(prices)
# Out:
# 24

# %%
# product reviews
reviews_list = soup.find_all('span', attrs = {'class':'PvbNMB'})
for r in reviews_list:
    print(r.text)
# Out:
# 114 Ratings & 15 Reviews
# 360 Ratings & 32 Reviews
# 3,593 Ratings & 275 Reviews
# 4,098 Ratings & 349 Reviews
# 7,551 Ratings & 663 Reviews
# 1,609 Ratings & 205 Reviews
# 4,098 Ratings & 349 Reviews
# 6,981 Ratings & 569 Reviews
# 1,595 Ratings & 113 Reviews
# 501 Ratings & 48 Reviews
# 695 Ratings & 44 Reviews
# 7,551 Ratings & 663 Reviews
# 2,144 Ratings & 155 Reviews
# 759 Ratings & 93 Reviews
# 4 Ratings & 1 Reviews
# 6,981 Ratings & 569 Reviews
# 13 Ratings & 3 Reviews
# 3,593 Ratings & 275 Reviews
# 1,574 Ratings & 104 Reviews
# 367 Ratings & 27 Reviews
# 70 Ratings & 13 Reviews
# 3,205 Ratings & 322 Reviews
# 9 Ratings & 0 Reviews
# 352 Ratings & 110 Reviews

# %%
len(reviews_list)
# Out:
# 24

# %%
# product feature list
features_list = soup.find_all('ul', attrs = {'class':'HwRTzP'})
for f in features_list:
    print(f.text)
# Out:
# AMD Ryzen Z1 Extreme Processor16 GB LPDDR5X RAMWindows 11 Home Operating System512 GB SSD22.35 cm (8.8 inch) Touchscreen Display1 Year Carry in + 1 Year Accidental Damage Protection
# Intel Core i3 Processor8 GB DDR4 RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 inch) DisplayMicrosoft Office Home 2024 (Lifetime Validity ) + Microsoft 365 Basic*(1-Year Validity), McAfee 1 year1 Year Onsite Warranty
# Intel Celeron Dual Core Processor12 GB LPDDR4X RAMWindows 11 Operating System512 GB SSD35.56 cm (14 Inch) Display1 Year Carry-in Warranty
# Intel Core i3 Processor (13th Gen)8 GB DDR5 RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 inch) DisplayIncluded Software- Microsoft Office Home 2024(includes Word, Excel, PowerPoint, and OneNote) (Lifetime Validity ) + Microsoft 365 Basic*(1-Year Validity), McAfee+TM Premium (1 year Validity)1 Year Onsite Warranty
# Intel Celeron Dual Core Processor8 GB DDR4 RAM64 bit Windows 11 Home Operating System128 GB SSD29.46 cm (11.6 inch) Display1 Year Warranty
# Intel Celeron Dual Core Processor4 GB LPDDR4 RAMWindows 11 Operating System128 GB SSD35.81 cm (14.1 inch) Display1 Year Onsite Warranty
# Intel Core i3 Processor (13th Gen)16 GB DDR5 RAMWindows 11 Home Operating System512 GB SSD35.56 cm (14 inch) DisplayIncluded Software- Microsoft Office Home 2024(includes Word, Excel, PowerPoint, and OneNote) (Lifetime Validity ) + Microsoft 365 Basic*(1-Year Validity), McAfee+TM Premium (1 year Validity)1 Year Onsite Warranty
# AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64 bit Windows 11 Operating System512 GB SSD39.62 cm (15.6 inch) DisplayOffice Home and Student 20211 Year Onsite + 1 Year Accidental Damage Protection
# AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAMWindows 11 Operating System1 TB SSD39.62 cm (15.6 Inch) Display1 Year Carry-in Warranty
# Qualcomm Snapdragon X Processor16 GB LPDDR5X RAMWindows 11 Home Operating System512 GB SSD38.86 cm (15.3 inch) DisplayOffice Home 20241 Year Onsite Warranty
# Intel Core i3 Processor (13th Gen)8 GB DDR4 RAM64 bit Windows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) Display1 Year Onsite Warranty
# Intel Celeron Dual Core Processor8 GB DDR4 RAM64 bit Windows 11 Home Operating System512 GB SSD29.46 cm (11.6 inch) Display1 Year Warranty
# MediaTek Kompanio 520 Processor4 GB LPDDR4X RAMChrome Operating System29.46 cm (11.6 Inch) Display1 Year Carry-in Warranty
# AMD Ryzen 3 Quad Core Processor8 GB DDR4 RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) Display1 Year Carry-in Warranty
# Intel Pentium Quad Core Processor4 GB DDR3 RAM64 bit Windows 11 Home Operating System128 GB SSD35.81 cm (14.1 inch) DisplayPre loaded windows APP1 Year Manufacturing Warranty (Battery And Charger Only 6 Month Warranty)
# AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 inch) DisplayMicrosoft Office Home & Student 20211 Year Onsite Warranty
# AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 Inch) DisplayMS Office Home 2024 + 1 year M365 Basic1 Year Onsite Warranty
# Intel Celeron Dual Core Processor8 GB LPDDR4X RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 inch) Display1 Year International Travelers Warranty (ITW)
# AMD Ryzen 3 Quad Core Processor8 GB LPDDR5 RAMWindows 11 Home Operating System512 GB SSD39.62 cm (15.6 Inch) DisplayMicrosoft Office Home 2024 + Microsoft 365 Basic1 Year Onsite Warranty
# AMD Ryzen 5 Quad Core Processor16 GB LPDDR5 RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) Display1 Year Onsite Warranty
# Intel Core i3 Processor (13th Gen)16 GB DDR4 RAM64 bit Windows 11 Home Operating System512 GB SSD39.62 cm (15.6 inch) DisplayMicrosoft Office 2021, Windows 11 Home3 Years Onsite Warranty
# AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) Display1 Year Carry-in Warranty
# Intel Core 3 Processor8 GB DDR4 RAMWindows 11 Home Operating System512 GB SSD38.1 cm (15 inch) Display1 Year Onsite Hardware Service
# MediaTek Helio G99 (MT8781) Processor8 GB LPDDR4X RAM64 bit Android Operating System35.81 cm (14.1 Inch) Display1 Year Onsite Warranty

# %%
len(features_list)
# Out:
# 24

# %%
url = 'https://www.flipkart.com/search?q=laptops&page=41'

for i in range(1,42):
    print(f'https://www.flipkart.com/search?q=laptops&page={i}')
# Out:
# https://www.flipkart.com/search?q=laptops&page=1
# https://www.flipkart.com/search?q=laptops&page=2
# https://www.flipkart.com/search?q=laptops&page=3
# https://www.flipkart.com/search?q=laptops&page=4
# https://www.flipkart.com/search?q=laptops&page=5
# https://www.flipkart.com/search?q=laptops&page=6
# https://www.flipkart.com/search?q=laptops&page=7
# https://www.flipkart.com/search?q=laptops&page=8
# https://www.flipkart.com/search?q=laptops&page=9
# https://www.flipkart.com/search?q=laptops&page=10
# https://www.flipkart.com/search?q=laptops&page=11
# https://www.flipkart.com/search?q=laptops&page=12
# https://www.flipkart.com/search?q=laptops&page=13
# https://www.flipkart.com/search?q=laptops&page=14
# https://www.flipkart.com/search?q=laptops&page=15
# https://www.flipkart.com/search?q=laptops&page=16
# https://www.flipkart.com/search?q=laptops&page=17
# https://www.flipkart.com/search?q=laptops&page=18
# https://www.flipkart.com/search?q=laptops&page=19
# https://www.flipkart.com/search?q=laptops&page=20
# https://www.flipkart.com/search?q=laptops&page=21
# https://www.flipkart.com/search?q=laptops&page=22
# https://www.flipkart.com/search?q=laptops&page=23
# https://www.flipkart.com/search?q=laptops&page=24
# https://www.flipkart.com/search?q=laptops&page=25
# https://www.flipkart.com/search?q=laptops&page=26
# https://www.flipkart.com/search?q=laptops&page=27
# https://www.flipkart.com/search?q=laptops&page=28
# https://www.flipkart.com/search?q=laptops&page=29
# https://www.flipkart.com/search?q=laptops&page=30
# https://www.flipkart.com/search?q=laptops&page=31
# https://www.flipkart.com/search?q=laptops&page=32
# https://www.flipkart.com/search?q=laptops&page=33
# https://www.flipkart.com/search?q=laptops&page=34
# https://www.flipkart.com/search?q=laptops&page=35
# https://www.flipkart.com/search?q=laptops&page=36
# https://www.flipkart.com/search?q=laptops&page=37
# https://www.flipkart.com/search?q=laptops&page=38
# https://www.flipkart.com/search?q=laptops&page=39
# https://www.flipkart.com/search?q=laptops&page=40
# https://www.flipkart.com/search?q=laptops&page=41

# %%
import numpy as np

title_data = []
price_data = []
rating_data = []
review_data = []
feature_data = []

for i in range(1,42):
    # step 1 : Identify the Url
    url = f'https://www.flipkart.com/search?q=laptops&page={i}'
     # step 2 : Extract the HTML code
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
    }
    response = requests.get(url, headers = headers)
    if response.status_code == 403:
        print("There's a 403 Error!")
        break

    # step 3 : Parse the HTML code to BeautifulSoup object
    html_code = response.text
    soup = BeautifulSoup(html_code)
    containers = soup.find_all('div',attrs = {'class':'ZFwe0M row'})
    for c in containers:
        # for each contianer scrape all data
        # Product title
        title = c.find('div', attrs = {'class': 'RG5Slk'})
        if title is None:
            title_data.append(np.nan)
        else:
            title_data.append(title.text)

    # Product Price
        price = c.find('div',attrs = {'class': 'hZ3P6w DeU9vF'}) 
        if price is None:
            price_data.append(np.nan)
        else:
            price_data.append(price.text)

    # Cutomer rating and review
        review = c.find('span',attrs = {'class':'PvbNMB'})
        if review is None:
            review_data.append(np.nan)
        else:
            review_data.append(review.text)

    # ratings
        rating = c.find('div', attrs = {'class': 'MKiFS6'})
        if rating is None:
            rating_data.append(np.nan)
        else:
            rating_data.append(rating.text)

        # features
        features = c.find('ul', attrs = {'class': 'HwRTzP'})
        if features is None:
            feature_data.append(np.nan)
        else:
            feature_data.append(features.text)

# %%
print("Product Title",len(title_data))
print("Product Price",len(price_data))
print("Product Rating",len(rating_data))
print("Product Review",len(review_data))
print("Product Feature",len(feature_data))
# Out:
# Product Title 984
# Product Price 984
# Product Rating 984
# Product Review 984
# Product Feature 984

# %%
# Creating DataFrame
df = pd.DataFrame({'Product Title':title_data,
                  'Product Price': price_data,
                  'Product Rating': rating_data,
                  'Product Review': review_data,
                  'Product Feature': feature_data})
df.head()
# Out:
#                                        Product Title Product Price  \
# 0  Lenovo Legion Go AMD Ryzen Z1 Extreme - (16 GB...       ₹73,990
# 1  ASUS Vivobook Go 15 (2025) with Office 2024 + ...       ₹39,990
# 2  Acer Aspire 3 Intel Celeron Dual Core N4500 - ...       ₹28,990
# 3  ASUS Expertbook P1 Intel Core i3 13th Gen 1315...       ₹36,990
# 4  Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...       ₹18,990
#
#   Product Rating               Product Review  \
# 0            4.4     114 Ratings & 15 Reviews
# 1            4.3     360 Ratings & 32 Reviews
# 2            3.9  3,593 Ratings & 275 Reviews
# 3            4.3  4,098 Ratings & 349 Reviews
# 4            3.8  7,551 Ratings & 663 Reviews
#
#                                      Product Feature
# 0  AMD Ryzen Z1 Extreme Processor16 GB LPDDR5X RA...
# 1  Intel Core i3 Processor8 GB DDR4 RAMWindows 11...
# 2  Intel Celeron Dual Core Processor12 GB LPDDR4X...
# 3  Intel Core i3 Processor (13th Gen)8 GB DDR5 RA...
# 4  Intel Celeron Dual Core Processor8 GB DDR4 RAM...

# %%
df.shape
# Out:
# (984, 5)

# %%
df.columns
# Out:
# Index(['Product Title', 'Product Price', 'Product Rating', 'Product Review',
#        'Product Feature'],
#       dtype='object')

# %%
df.to_csv('laptop_raw_data.csv',index = False)

# %% [markdown]
# # 2) Washing machine

# %%
# identify the URL
url = 'https://www.flipkart.com/search?q=Washing%20Machine'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"}

# Loading the webpage using requsts library
response = requests.get(url, headers= headers)
response.status_code
# Out:
# 200

# %%
html_code = 
response.text
html_code[:2000]
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.aa1465.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.fbaef9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png"/><link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png"/><link rel="apple-touch-icon" href="/apple-touch-icon-57x57.png"/><meta name="twitter:card" content="app"><meta name="twitter:site" content="@flipkart"><meta name="twitter:creator" content="@flipkart"><meta name="twitter:title" content="Washing Machine- Buy Products Online at Best Price in India - All Categories | Flipkart.com"><meta name="twitter:description" content="Shop for electronics, apparels & more using our Flipkart app Free shipping & COD."><meta name="twitter:app:country" content="in"><meta name="al:ios:app_name" content="Flipkart"><meta name="al:ios:app_store_id" content="742044692"><meta name="twitter:app:name:iphone" content="Flipkart"><meta name="twitter:app:id:iphone" content="742044692"><meta name="twitter:app:url:iphone" content="http://dl.flipk'

# %%
soup = BeautifulSoup(html_code)
soup.text[:2000]
# Out:
# '  Washing Machine- Buy Products Online at Best Price in India - All Categories | Flipkart.com     Explore PlusLoginBecome a Seller More CartFiltersCATEGORIESHome & KitchenHome AppliancesWashing MachinesFunction TypePrice.......Min₹10000₹20000₹30000₹40000₹50000to₹10000₹20000₹30000₹40000₹50000₹50000+?Ideal for Family SizeLarge FamiliesFamily of 4Family of 3Single & CoupleBrandSamsungLGWhirlpoolIFBBOSCHGodrej40 MORECapacityLatest TechnologyDiscountAvailabilityGST Invoice AvailableThemeOffersSpecial PriceBuy More, Save MoreCustomer Ratings4★ & above3★ & above2★ & above1★ & aboveNeed help?Help me decideHomeHome & KitchenHome AppliancesWashing MachinesShowing 1 – 24 of 1,059 results for "Washing Machine"Sort ByRelevancePopularityPrice -- Low to HighPrice -- High to LowNewest FirstDiscountAdd to CompareMarQ by Flipkart 6 kg 5 Star Rating Innowash Range Semi Automatic Top Load Washing Machine White, Maro...4.331,138 Ratings\xa0&\xa02,698 Reviews1350 rpm Max Speed5 Star Rating2 Years Warranty on Product and 04 Years Special Warranty on Wash Motor₹6,790₹11,99043% offUpto ₹1,330 Off on ExchangeBank OfferAdd to Comparerealme TechLife 7 kg 5 Star Rating Fabric Safe Wash Fully Automatic Top Load Washing Machine Black, Gr...4.116,733 Ratings\xa0&\xa01,674 Reviews700 rpm Max Speed5 Star Rating2 Years Warranty on Product and 05 Years Special Warranty on Wash Motor₹11,090₹21,99049% offUpto ₹1,330 Off on ExchangeBank OfferAdd to Comparerealme TechLife 7.5 kg 5 Star Rating Semi Automatic Top Load Washing Machine Black, Grey4.298,318 Ratings\xa0&\xa08,436 Reviews1400 RPM Max Speed5 Star Rating2 Years Warranty on Product and 05 Years Special Warranty on Wash Motor₹7,790₹13,99044% offUpto ₹1,330 Off on ExchangeBank OfferAdd to Comparerealme TechLife 7 kg 5 Star rating Semi Automatic Top Load Washing Machine White, Black4.298,318 Ratings\xa0&\xa08,436 Reviews1400 RPM Max Speed5 Star Rating2 Years Warranty on Product and 05 Years Special Warranty on Wash Motor₹7,390₹12,49040% offOnly 2 leftUpto ₹1,330 Off on Excha'

# %%
#extracting all Washing Machines on the wepage
# Product title
titles = soup.find_all('div',attrs = {'class':'RG5Slk'})
for t in titles:
    print(t.text)
# Out:
# MarQ by Flipkart 6 kg 5 Star Rating Innowash Range Semi Automatic Top Load Washing Machine White, Maro...
# realme TechLife 7 kg 5 Star Rating Fabric Safe Wash Fully Automatic Top Load Washing Machine Black, Gr...
# realme TechLife 7.5 kg 5 Star Rating Semi Automatic Top Load Washing Machine Black, Grey
# realme TechLife 7 kg 5 Star rating Semi Automatic Top Load Washing Machine White, Black
# Samsung 6.5 kg 5 star, Air Turbo Drying Semi Automatic Top Load Washing Machine Blue, Grey
# MarQ by Flipkart by Flipkart 8 kg Washer only Maroon, White
# MOTOROLA 10 kg 5 star rating Midnight Series Semi Automatic Top Load Washing Machine Black
# MarQ by Flipkart 7 kg 5 Star Rating Innowash Range Semi Automatic Top Load Washing Machine Blue, White
# Thomson 10 kg 5 Star Aqua Magic Double Waterfall Semi Automatic Top Load Washing Machine Black
# Samsung 7 kg 5 star, Air Turbo Drying Semi Automatic Top Load Washing Machine Grey, Purple
# realme TechLife 8.5 kg 5 Star rating Semi Automatic Top Load Washing Machine Grey, Black
# realme TechLife 7.5 kg 5 Star Rating Fabric Safe Wash Fully Automatic Top Load Washing Machine Grey
# Voltas Beko 9 kg Semi Automatic Top Load Washing Machine Black, Grey
# realme TechLife 8 kg Soft closing Glass lid Fully Automatic Top Load Washing Machine with In-built Hea...
# Voltas Beko by A Tata Product 7 kg Semi Automatic Top Load Washing Machine Maroon, White
# Thomson 8 kg 5 Star Aqua Magic Grande Series with Floral Toughened Glass and Double Waterfall Semi Aut...
# Voltas Beko by A Tata Product 14 kg Semi Automatic Top Load Washing Machine Blue
# LG 8.5 kg 5 Star with Roller Jet Pulsator with Soak, Wind Jet Dry and Collar Scrubber Semi Automatic T...
# Voltas Beko 6.5 kg Semi Automatic Top Load Washing Machine Blue
# Samsung 7 kg 5 Star, Ecobubble, Soft Closing Door, Digital Inverter Fully Automatic Top Load Washing M...
# VW 9.5 kg Semi Automatic Top Load Washing Machine Yellow, Black, Grey
# MarQ by Flipkart 7.5 kg 5 Star Rating Innowash Range Semi Automatic Top Load Washing Machine Maroon, W...
# Voltas Beko 7 kg Semi Automatic Top Load Washing Machine White, Maroon
# Voltas Beko by A Tata Product 8.5 kg 5 Star Semi Automatic Top Load Washing Machine Blue

# %%
# product rating
ratings = soup.find_all('div', attrs = {'class':'MKiFS6'})
for r in ratings:
    print(r.text)
# Out:
# 4.3
# 4.1
# 4.2
# 4.2
# 4.4
# 4.2
# 4.3
# 4.3
# 4.1
# 4.4
# 4.2
# 4.1
# 4.3
# 4
# 4.3
# 4.1
# 4.3
# 4.5
# 4.3
# 4.3
# 4.3
# 4.3
# 4.3
# 4.3
# 4.1
# 5
# 1
# 4.3
# 5
# 5
# 4.5
# 5
# 5
# 4.3
# 4
# 5
# 4
# 4
# 5
